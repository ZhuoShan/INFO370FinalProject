# %%
import pandas as pd;
import numpy as np
import statsmodels.api as sm
import matplotlib
import matplotlib.pyplot as plt
matplotlib.style.use('ggplot')
# %matplotlib inline

FinalData = pd.read_csv('finalDate.csv')

# %%
FinalData
# Out:
#       Unnamed: 0  Price  Year  Mileage          City State        Make  \
# 0              0  15893  2015    30608       HOUSTON    TX      NISSAN
# 1              1  13950  2015    95099       HOUSTON    TX      NISSAN
# 2              2  29900  2015    24384       HOUSTON    TX   CHEVROLET
# 3              3  26505  2014    42980       HOUSTON    TX   CHEVROLET
# 4              4  16400  2017    25446       HOUSTON    TX      NISSAN
# 5              5  18991  2014    33658       HOUSTON    TX      NISSAN
# 6              6  34000  2014    63120       HOUSTON    TX         GMC
# 7              7  27988  2014    30321       HOUSTON    TX         GMC
# 8              8  17986  2015    21448       HOUSTON    TX       HONDA
# 9              9  24977  2014    29344       HOUSTON    TX   CHEVROLET
# 10            10  34459  2015    94129       HOUSTON    TX        FORD
# 11            11  14225  2016    36317       HOUSTON    TX      NISSAN
# ...

# %%
FinalData.drop(FinalData.columns[0],axis=1,inplace=True)

# %%
FinalData['Population'] = pd.to_numeric(FinalData['Population'], errors='coerce')
FinalData['Population'] = FinalData['Population'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-16f88d183871> in <module>()
#       1 FinalData['Population'] = pd.to_numeric(FinalData['Population'], errors='coerce')
# ----> 2 FinalData['Population'] = FinalData['Population'].astype(int)
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     175                 else:
#     176                     kwargs[new_arg_name] = new_arg_value
# --> 177             return func(*args, **kwargs)
#     178         return wrapper
#     179     return _deprecate_kwarg
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors, **kwargs)
#    4995             # else, only a single dtype is given
#    4996             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 4997                                          **kwargs)
# ...

# %%
lm = sm.OLS(FinalData.DepreciationRate, sm.add_constant(FinalData.Population)).fit()

# %%
FinalData
# Out:
#       Price  Year  Mileage          City State        Make      Model  \
# 0     15893  2015    30608       HOUSTON    TX      NISSAN  ALTIMA2.5
# 1     13950  2015    95099       HOUSTON    TX      NISSAN  ALTIMA2.5
# 2     29900  2015    24384       HOUSTON    TX   CHEVROLET  SILVERADO
# 3     26505  2014    42980       HOUSTON    TX   CHEVROLET  SILVERADO
# 4     16400  2017    25446       HOUSTON    TX      NISSAN  ALTIMA2.5
# 5     18991  2014    33658       HOUSTON    TX      NISSAN  ALTIMA2.5
# 6     34000  2014    63120       HOUSTON    TX         GMC     SIERRA
# 7     27988  2014    30321       HOUSTON    TX         GMC     SIERRA
# 8     17986  2015    21448       HOUSTON    TX       HONDA     ACCORD
# 9     24977  2014    29344       HOUSTON    TX   CHEVROLET  SILVERADO
# 10    34459  2015    94129       HOUSTON    TX        FORD   F-1504WD
# 11    14225  2016    36317       HOUSTON    TX      NISSAN  ALTIMA2.5
# ...

# %%
print(lm.summary())

# %%
FinalData.describe()

# %%
FinalData.Make.value_counts()

# %%
plt.scatter(FinalData.Mileage,FinalData.DepreciationRate)
plt.plot(FinalData.Mileage, lm.predict(), color = 'black', c = 'DarkBlue')
plt.show()
