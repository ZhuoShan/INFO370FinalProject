# %%
import pandas as pd;
import numpy as np
import statsmodels.api as sm
import matplotlib
import matplotlib.pyplot as plt
matplotlib.style.use('ggplot')
# %matplotlib inline

FinalData = pd.read_csv('finalDate.csv')

# %%
FinalData.drop(FinalData.columns[0],axis=1,inplace=True)

# %%
#FinalData['Population'] = pd.to_numeric(FinalData['Population'], errors='coerce')
#FinalData['Population'] = FinalData['Population'].astype(int)

# %%
FinalData

# %%
FinalData['Population'] = FinalData['Population'].str.replace(',', '')

# %%
FinalData['Population'] = pd.to_numeric(FinalData['Population'], errors='coerce')
FinalData['Population'] = FinalData['Population'].astype(int)

# %%
FinalData

# %%
lm = sm.OLS(FinalData.DepreciationRate, sm.add_constant(FinalData.Mileage)).fit()

# %%
print(lm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       DepreciationRate   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     2.907
# Date:                Sat, 17 Nov 2018   Prob (F-statistic):             0.0885
# Time:                        16:23:39   Log-Likelihood:                 179.67
# No. Observations:                1123   AIC:                            -355.3
# Df Residuals:                    1121   BIC:                            -345.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.5857      0.016     36.274      0.000       0.554       0.617
# Gdp         6.659e-08   3.91e-08      1.705      0.088      -1e-08    1.43e-07
# ==============================================================================
# Omnibus:                       74.710   Durbin-Watson:                   2.010
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               26.797
# Skew:                          -0.006   Prob(JB):                     1.52e-06
# Kurtosis:                       2.243   Cond. No.                     1.08e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.08e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
X = FinalData[['Mileage', 'Gdp', 'serviceTime']]
X = sm.add_constant(X)
Multi_lm2 = sm.OLS(FinalData.DepreciationRate, X).fit()
print(Multi_lm2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       DepreciationRate   R-squared:                       0.315
# Model:                            OLS   Adj. R-squared:                  0.313
# Method:                 Least Squares   F-statistic:                     171.7
# Date:                Sat, 17 Nov 2018   Prob (F-statistic):           1.47e-91
# Time:                        16:33:38   Log-Likelihood:                 390.83
# No. Observations:                1123   AIC:                            -773.7
# Df Residuals:                    1119   BIC:                            -753.6
# Df Model:                           3
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const           0.7453      0.015     49.202      0.000       0.716       0.775
# Mileage     -8.582e-07      2e-07     -4.285      0.000   -1.25e-06   -4.65e-07
# Gdp          1.081e-07   3.25e-08      3.330      0.001    4.44e-08    1.72e-07
# serviceTime    -0.0282      0.003    -10.818      0.000      -0.033      -0.023
# ==============================================================================
# Omnibus:                      108.068   Durbin-Watson:                   2.067
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               53.703
# Skew:                           0.366   Prob(JB):                     2.18e-12
# Kurtosis:                       2.218   Cond. No.                     1.24e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.24e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
gdpFS = FinalData['Gdp']
gdpFS = sm.add_constant(gdpFS)
Multi_lmGDP = sm.OLS(FinalData.DepreciationRate, gdpFS).fit()
print(Multi_lmGDP.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       DepreciationRate   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     2.907
# Date:                Sat, 17 Nov 2018   Prob (F-statistic):             0.0885
# Time:                        14:32:08   Log-Likelihood:                 179.67
# No. Observations:                1123   AIC:                            -355.3
# Df Residuals:                    1121   BIC:                            -345.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.5857      0.016     36.274      0.000       0.554       0.617
# Gdp         6.659e-08   3.91e-08      1.705      0.088      -1e-08    1.43e-07
# ==============================================================================
# Omnibus:                       74.710   Durbin-Watson:                   2.010
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               26.797
# Skew:                          -0.006   Prob(JB):                     1.52e-06
# Kurtosis:                       2.243   Cond. No.                     1.08e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.08e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
milFS = FinalData[['Mileage', 'Gdp']]
milFS = sm.add_constant(milFS)
Multi_lmMIL = sm.OLS(FinalData.DepreciationRate, milFS).fit()
print(Multi_lmMIL.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       DepreciationRate   R-squared:                       0.244
# Model:                            OLS   Adj. R-squared:                  0.242
# Method:                 Least Squares   F-statistic:                     180.3
# Date:                Sat, 17 Nov 2018   Prob (F-statistic):           1.26e-68
# Time:                        15:47:58   Log-Likelihood:                 334.97
# No. Observations:                1123   AIC:                            -663.9
# Df Residuals:                    1120   BIC:                            -648.9
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.7139      0.016     45.708      0.000       0.683       0.745
# Mileage     -2.53e-06   1.34e-07    -18.891      0.000   -2.79e-06   -2.27e-06
# Gdp         8.927e-08    3.4e-08      2.622      0.009    2.25e-08    1.56e-07
# ==============================================================================
# Omnibus:                       74.246   Durbin-Watson:                   2.032
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               52.108
# Skew:                           0.418   Prob(JB):                     4.84e-12
# Kurtosis:                       2.356   Cond. No.                     1.21e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.21e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
STFS = FinalData['Gdp']
STFS = sm.add_constant(STFS)
Multi_lmST = sm.OLS(FinalData.DepreciationRate, STFS).fit()
print(Multi_lmST.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       DepreciationRate   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     2.907
# Date:                Sat, 17 Nov 2018   Prob (F-statistic):             0.0885
# Time:                        15:48:54   Log-Likelihood:                 179.67
# No. Observations:                1123   AIC:                            -355.3
# Df Residuals:                    1121   BIC:                            -345.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.5857      0.016     36.274      0.000       0.554       0.617
# Gdp         6.659e-08   3.91e-08      1.705      0.088      -1e-08    1.43e-07
# ==============================================================================
# Omnibus:                       74.710   Durbin-Watson:                   2.010
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               26.797
# Skew:                          -0.006   Prob(JB):                     1.52e-06
# Kurtosis:                       2.243   Cond. No.                     1.08e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.08e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
print(Multi_lm2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       DepreciationRate   R-squared:                       0.244
# Model:                            OLS   Adj. R-squared:                  0.242
# Method:                 Least Squares   F-statistic:                     180.3
# Date:                Sat, 17 Nov 2018   Prob (F-statistic):           1.26e-68
# Time:                        13:34:22   Log-Likelihood:                 334.97
# No. Observations:                1123   AIC:                            -663.9
# Df Residuals:                    1120   BIC:                            -648.9
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.7139      0.016     45.708      0.000       0.683       0.745
# Mileage     -2.53e-06   1.34e-07    -18.891      0.000   -2.79e-06   -2.27e-06
# Gdp         8.927e-08    3.4e-08      2.622      0.009    2.25e-08    1.56e-07
# ==============================================================================
# Omnibus:                       74.246   Durbin-Watson:                   2.032
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               52.108
# Skew:                           0.418   Prob(JB):                     4.84e-12
# Kurtosis:                       2.356   Cond. No.                     1.21e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.21e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
X = FinalData[['Mileage', 'Gdp', 'serviceTime']]
X = sm.add_constant(X)
Multi_lm3 = sm.OLS(FinalData.DepreciationRate, X).fit()
print(Multi_lm3.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       DepreciationRate   R-squared:                       0.244
# Model:                            OLS   Adj. R-squared:                  0.242
# Method:                 Least Squares   F-statistic:                     180.3
# Date:                Sat, 17 Nov 2018   Prob (F-statistic):           1.26e-68
# Time:                        16:22:19   Log-Likelihood:                 334.97
# No. Observations:                1123   AIC:                            -663.9
# Df Residuals:                    1120   BIC:                            -648.9
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.7139      0.016     45.708      0.000       0.683       0.745
# Mileage     -2.53e-06   1.34e-07    -18.891      0.000   -2.79e-06   -2.27e-06
# Gdp         8.927e-08    3.4e-08      2.622      0.009    2.25e-08    1.56e-07
# ==============================================================================
# Omnibus:                       74.246   Durbin-Watson:                   2.032
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               52.108
# Skew:                           0.418   Prob(JB):                     4.84e-12
# Kurtosis:                       2.356   Cond. No.                     1.21e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.21e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
FinalData.describe()
# Out:
#               Price         Year        Mileage  Original Price  serviceTime  \
# count   1123.000000  1123.000000    1123.000000     1123.000000  1123.000000
# mean   20525.684773  2013.430098   54086.666963    33472.310775     4.569902
# std     7931.377833     3.081667   40111.727925     5424.233620     3.081667
# min     2995.000000  2001.000000      51.000000    24500.000000     1.000000
# 25%    14500.000000  2012.000000   27645.500000    29800.000000     3.000000
# 50%    18995.000000  2014.000000   41668.000000    31780.000000     4.000000
# 75%    26989.500000  2015.000000   72712.500000    38200.000000     6.000000
# max    43900.000000  2017.000000  298699.000000    45000.000000    17.000000
#
#        DepreciationRate            Gdp    Population
# count       1123.000000    1123.000000  1.123000e+03
# mean           0.611157  382170.152271  1.988258e+06
# std            0.206555  157755.051340  3.917321e+05
# min            0.116928  129298.000000  1.541456e+06
# 25%            0.465658  129298.000000  1.541456e+06
# 50%            0.596531  490074.000000  2.340814e+06
# 75%            0.782697  490074.000000  2.340814e+06
# max            0.999874  490074.000000  2.340814e+06

# %%
FinalData.Make.value_counts()
# Out:
# CHEVROLET     326
# NISSAN        180
# JEEP          132
# HONDA         113
# VOLKSWAGEN     95
# BMW            92
# HYUNDAI        70
# GMC            69
# FORD           46
# Name: Make, dtype: int64

# %%
plt.scatter(FinalData.Mileage,FinalData.DepreciationRate)
plt.plot(FinalData.Mileage, lm.predict(), c = 'blue')
plt.title('Linear Regression Model for Mileage')
plt.xlabel('Mileage')
plt.ylabel('Depreciation Rate')
plt.show()

# %%
plt.scatter(FinalData.Mileage,FinalData.DepreciationRate)
plt.plot(FinalData.Mileage, Multi_lm2.predict(), c = 'blue')
plt.title('Multiple Linear Regression Model for Mileage and GDP')
plt.xlabel('Mileage')
plt.ylabel('Depreciation Rate')
plt.show()

# %%
fig = plt.figure(figsize=(20, 12))
fig = sm.graphics.plot_partregress_grid(Multi_lm2, fig=fig)

# %%
plt.scatter(FinalData.Mileage,FinalData.DepreciationRate)
plt.plot(FinalData.Mileage, Multi_lm3.predict(), c = 'blue')
plt.title('Multiple Linear Regression Model for Mileage, GDP and Service Time')
plt.xlabel('Mileage')
plt.ylabel('Depreciation Rate')
plt.show()
